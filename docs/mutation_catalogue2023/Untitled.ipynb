# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\drugresistance\\docs\\mutation_catalogue2023'

# %%
import pandas as pd

# %%
file = pd.read_csv("GenotypeResistance.csv",sep="\t")

# %%
file['Genotypic Resistance'].value_counts()
# Out:
# S    1583606
# R     273566
# U      31228
# Name: Genotypic Resistance, dtype: int64

# %%
file[file['Genotypic Resistance']=="R"]
# Out:
#         BioSample Accession          Drug Genotypic Resistance  \
# 14           SAMEA114640612  Pyrazinamide                    R
# 15           SAMEA114640610  Pyrazinamide                    R
# 17           SAMEA114640611  Pyrazinamide                    R
# 33           SAMEA114640614    Rifampicin                    R
# 54             SAMN37847922  Streptomycin                    R
# ...                     ...           ...                  ...
# 1888376        SAMN48386462    Ethambutol                    R
# 1888381        SAMN48386466    Ethambutol                    R
# 1888385        SAMN48386469    Rifampicin                    R
# 1888392        SAMN48386479  Streptomycin                    R
# 1888396        SAMN48386485    Ethambutol                    R
#
#                   Variant
# 14       pncA_p.Gln141Pro
# 15        pncA_p.Asp63Ala
# 17        pncA_p.Asp63Ala
# 33       rpoB_p.Ser450Leu
# 54        rpsL_p.Lys43Arg
# ...                   ...
# ...

# %%
file[file['Genotypic Resistance']=="S"]
# Out:
#         BioSample Accession          Drug Genotypic Resistance Variant
# 0            SAMEA114663522     Delamanid                    S     NaN
# 1            SAMEA114663510    Rifampicin                    S     NaN
# 2            SAMEA114663518    Ethambutol                    S     NaN
# 3            SAMEA114663527     Isoniazid                    S     NaN
# 4            SAMEA114663528      Amikacin                    S     NaN
# ...                     ...           ...                  ...     ...
# 1888394        SAMN48386481  Moxifloxacin                    S     NaN
# 1888395        SAMN48386483   Bedaquiline                    S     NaN
# 1888397        SAMN48386485  Levofloxacin                    S     NaN
# 1888398        SAMN48386487  Streptomycin                    S     NaN
# 1888399        SAMN48386487    Pretomanid                    S     NaN
#
# [1583606 rows x 4 columns]

# %%
file
# Out:
#         BioSample Accession          Drug Genotypic Resistance  \
# 0            SAMEA114663522     Delamanid                    S
# 1            SAMEA114663510    Rifampicin                    S
# 2            SAMEA114663518    Ethambutol                    S
# 3            SAMEA114663527     Isoniazid                    S
# 4            SAMEA114663528      Amikacin                    S
# ...                     ...           ...                  ...
# 1888395        SAMN48386483   Bedaquiline                    S
# 1888396        SAMN48386485    Ethambutol                    R
# 1888397        SAMN48386485  Levofloxacin                    S
# 1888398        SAMN48386487  Streptomycin                    S
# 1888399        SAMN48386487    Pretomanid                    S
#
#                   Variant
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# ...

# %%
file[file['Genotypic Resistance']=="U"]
# Out:
#         BioSample Accession          Drug Genotypic Resistance Variant
# 107            SAMN37848404   Capreomycin                    U     NaN
# 802            SAMN37848600     Linezolid                    U     NaN
# 919            SAMN37848404     Kanamycin                    U     NaN
# 1392           SAMN37848528     Linezolid                    U     NaN
# 1458           SAMN37848357     Linezolid                    U     NaN
# ...                     ...           ...                  ...     ...
# 1888046        SAMN48386468      Amikacin                    U     NaN
# 1888047        SAMN48386468     Linezolid                    U     NaN
# 1888101        SAMN48386468   Capreomycin                    U     NaN
# 1888163        SAMN48386468     Kanamycin                    U     NaN
# 1888383        SAMN48386468  Streptomycin                    U     NaN
#
# [31228 rows x 4 columns]
